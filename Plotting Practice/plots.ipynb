# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(3, 2, 'x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(3, 2, 'x')
ax = plt.gca()
ax.axis([0, 6, 0, 10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %% [markdown]
# # Scatter Plots

# %%
import numpy as np
x = np.array([1, 2, 3, 4, 5, 6])
y = x

plt.figure()
plt.scatter(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = x

colors = []
for i in range(len(x)):
    if i % 2 == 0:
        colors.append('green')
    else:
        colors.append('red')

plt.figure()
plt.scatter(x, y, s = 50, c = colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Line Plots

# %%
import numpy as np
x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = x ** 2

plt.figure()
plt.plot(x, '-o', y, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x129e44790>,
#  <matplotlib.lines.Line2D at 0x129e2c2d0>]

# %%
plt.xlabel('X Index')
plt.ylabel('Y Index')
plt.title('X vs Y')

plt.legend(['X', 'Y'])

# %%
plt.plot([10,20,30,40,50],'--r')

# %%
plt.legend(['X', 'Y', 'Competition'])

# %%
plt.gca().fill_between(range(len(x)),
                      x, y,
                      facecolor = 'blue',
                      alpha = 0.25)
