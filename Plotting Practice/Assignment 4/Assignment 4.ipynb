# %% [markdown]
# # Assignment 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.use('seaborn-colorblind')

# %%
snow_df = pd.read_csv('snowfall.csv')
snow_df.head()
# Out:
#        Country or Territory                  Station Name  WMO Station Number  \
# 0  UNITED STATES OF AMERICA  BARROW/W. POST W. ROGERS, AK             70026.0
# 1  UNITED STATES OF AMERICA       KOTZEBUE/RALPH WIEN, AK             70133.0
# 2  UNITED STATES OF AMERICA              BETTLES/FIELD AK             70174.0
# 3  UNITED STATES OF AMERICA                      NOME, AK             70200.0
# 4  UNITED STATES OF AMERICA     BETHEL/BETHEL AIRPORT, AK             70219.0
#
#    National Station Id Number     Period  Element-Statistic Qualifier Code  \
# 0                    500546.0  1961-1990                               NaN
# 1                    505076.0  1961-1990                               NaN
# 2                    500761.0  1961-1990                               NaN
# 3                    506496.0  1961-1990                               NaN
# 4                    500754.0  1961-1990                               NaN
#
# ...

# %%
temp_df = pd.read_excel('Temp_1961_1990.xls')
temp_df = temp_df.rename(columns = {' Month' : 'Month'})
temp_df.head()
# Out:
#         tas  \tYear  Month  Country   ISO3   ISO2
# 0  -5.21460    1961      1      USA    NaN    NaN
# 1  -3.21400    1961      2      USA    NaN    NaN
# 2  -0.15080    1961      3      USA    NaN    NaN
# 3   4.52072    1961      4      USA    NaN    NaN
# 4  11.86120    1961      5      USA    NaN    NaN

# %%
rain_df = pd.read_excel('Rain_1961_1990.xls')
rain_df = rain_df.rename(columns = {' Month' : 'Month'})
rain_df.head()
# Out:
#         pr  \tYear  Month  Country   ISO3   ISO2
# 0  29.8744    1961      1      USA    NaN    NaN
# 1  52.7065    1961      2      USA    NaN    NaN
# 2  59.5436    1961      3      USA    NaN    NaN
# 3  48.6108    1961      4      USA    NaN    NaN
# 4  57.4379    1961      5      USA    NaN    NaN

# %%
Jan = snow_df['Jan'].mean()
Feb = snow_df['Feb'].mean()
Mar = snow_df['Mar'].mean()
Apr = snow_df['Apr'].mean()
May = snow_df['May'].mean()
Jun = snow_df['Jun'].mean()
Jul = snow_df['Jul'].mean()
Aug = snow_df['Aug'].mean()
Sep = snow_df['Sep'].mean()
Oct = snow_df['Oct'].mean()
Nov = snow_df['Nov'].mean()
Dec = snow_df['Dec'].mean()

# %%
weather_df = pd.DataFrame({'Snowfall' : [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]})
weather_df
# Out:
#         Snowfall
# 0   32910.929764
# 1   32099.560367
# 2   32814.367087
# 3   35263.127507
# 4   35805.531129
# 5   30106.764987
# 6   29014.876535
# 7   28906.219423
# 8   32462.127717
# 9   35576.560892
# 10  34939.955171
# 11  33215.316745

# %%
monthly_temp = temp_df.groupby('Month').mean()['tas']
Jan = monthly_temp.iloc[0]
Feb = monthly_temp.iloc[1]
Mar = monthly_temp.iloc[2]
Apr = monthly_temp.iloc[3]
May = monthly_temp.iloc[4]
Jun = monthly_temp.iloc[5]
Jul = monthly_temp.iloc[6]
Aug = monthly_temp.iloc[7]
Sep = monthly_temp.iloc[8]
Oct = monthly_temp.iloc[9]
Nov = monthly_temp.iloc[10]
Dec = monthly_temp.iloc[11]

# %%
weather_df['Temperature'] = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
weather_df
# Out:
#         Snowfall  Temperature
# 0   32910.929764    -6.266277
# 1   32099.560367    -4.228557
# 2   32814.367087     0.161376
# 3   35263.127507     5.987872
# 4   35805.531129    12.186650
# 5   30106.764987    17.210970
# 6   29014.876535    20.030330
# 7   28906.219423    18.935290
# 8   32462.127717    14.488357
# 9   35576.560892     7.789156
# 10  34939.955171     0.468967
# 11  33215.316745    -4.694447

# %%
monthly_rain = rain_df.groupby('Month').mean()['pr']
monthly_rain.iloc[0]
Jan = monthly_rain.iloc[0]
Feb = monthly_rain.iloc[1]
Mar = monthly_rain.iloc[2]
Apr = monthly_rain.iloc[3]
May = monthly_rain.iloc[4]
Jun = monthly_rain.iloc[5]
Jul = monthly_rain.iloc[6]
Aug = monthly_rain.iloc[7]
Sep = monthly_rain.iloc[8]
Oct = monthly_rain.iloc[9]
Nov = monthly_rain.iloc[10]
Dec = monthly_rain.iloc[11]

# %%
weather_df['Rainfall'] = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
weather_df
# Out:
#         Snowfall  Temperature   Rainfall
# 0   32910.929764    -6.266277  44.567710
# 1   32099.560367    -4.228557  41.915983
# 2   32814.367087     0.161376  51.627430
# 3   35263.127507     5.987872  49.433157
# 4   35805.531129    12.186650  60.396267
# 5   30106.764987    17.210970  64.473557
# 6   29014.876535    20.030330  65.537783
# 7   28906.219423    18.935290  65.038193
# 8   32462.127717    14.488357  61.432697
# 9   35576.560892     7.789156  49.504067
# 10  34939.955171     0.468967  50.642860
# 11  33215.316745    -4.694447  50.472827

# %%
weather_df['Snowfall'] = weather_df['Snowfall'] / 1000
weather_df
# Out:
#      Snowfall  Temperature   Rainfall
# 0   32.910930    -6.266277  44.567710
# 1   32.099560    -4.228557  41.915983
# 2   32.814367     0.161376  51.627430
# 3   35.263128     5.987872  49.433157
# 4   35.805531    12.186650  60.396267
# 5   30.106765    17.210970  64.473557
# 6   29.014877    20.030330  65.537783
# 7   28.906219    18.935290  65.038193
# 8   32.462128    14.488357  61.432697
# 9   35.576561     7.789156  49.504067
# 10  34.939955     0.468967  50.642860
# 11  33.215317    -4.694447  50.472827

# %%
weather_df.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
weather_df
# Out:
#       Snowfall  Temperature   Rainfall
# Jan  32.910930    -6.266277  44.567710
# Feb  32.099560    -4.228557  41.915983
# Mar  32.814367     0.161376  51.627430
# Apr  35.263128     5.987872  49.433157
# May  35.805531    12.186650  60.396267
# Jun  30.106765    17.210970  64.473557
# Jul  29.014877    20.030330  65.537783
# Aug  28.906219    18.935290  65.038193
# Sep  32.462128    14.488357  61.432697
# Oct  35.576561     7.789156  49.504067
# Nov  34.939955     0.468967  50.642860
# Dec  33.215317    -4.694447  50.472827

# %%
X = weather_df.index.tolist()
Y1 = weather_df['Snowfall'].tolist()
Y2 = weather_df['Temperature'].tolist()
Y3 = weather_df['Rainfall'].tolist()

plt.plot(X, Y1, '-s', label = "Snowfall (in 0.1*m)")
plt.plot(X, Y2, '-*', label = "Temperature (in $\,^{\circ}\mathrm{C}$)")
plt.plot(X, Y3, '-o', label = "Rainfall (in 0.1*cm)")

plt.title('Average Temperature, Snowfall and Rainfall in United States(1961-1990)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
